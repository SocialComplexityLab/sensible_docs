# %% [markdown]
# # Sms

# %% [markdown]
# SMS data collected every 24 hours.

# %%
import pandas
from sensible_raw.loaders import loader

# %% [markdown]
# ### Field description

# %%
loader.docs("sms")
# Out:
#                                                                                                                                                                         address  \
# 0  Identifier for the caller/callee (depends on type).  > 0 values represent users from the study and match the user_id column, values < 0 represent devices outside the study.
#
#                                  timestamp  \
# 0  Unix-time of the sample in milliseconds
#
#                                                                                  type  \
# 0  Type of the call event: 1 - sent message, 2 - received message, 3 - draft message.
#
#                                                                                                                                      user
# 0  Unique identifier for each user. Note: it is an id, not a counter for users. Numbers higher than 850 doesn't mean there are more users

# %% [markdown]
# ### Load data

# %%
loader.load_data("sms", "january_2014", as_dataframe=True)
# Out:
#         address  status      timestamp  type  user
# 0        -99860      -1  1389444326000     3   228
# 1           284      -1  1389444392000     2   228
# 2           284      -1  1389444492000     1   228
# 3           845      -1  1389444959000     2   228
# 4           845      -1  1389445031000     1   228
# 5           845      -1  1389445061000     2   228
# 6           845      -1  1389445084000     1   228
# 7           845      -1  1389445130000     2   228
# 8           845      -1  1389445163000     1   228
# 9           845      -1  1389445218000     2   228
# 10          845      -1  1389445251000     1   228
# 11          845      -1  1389445367000     2   228
# 12          845      -1  1389445439000     1   228
# 13          284      -1  1389446061000     2   228
# 14       -99860      -1  1389470268000     3   228
# 15       -99347      -1  1389086086000     2   228
# 16       -99347      -1  1389089393000     2   228
# ...

# %% [markdown]
# ### Data quality

# %%
# Plots the number of active users in each month of the experiment (September 2013 - February 2016)
# %run ../data_quality.py
# %matplotlib inline

plot_monthly_active_users('sms')
