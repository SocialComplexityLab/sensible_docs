# %% [markdown]
# # Bluetooth

# %% [markdown]
# Bluetooth data was collected by having the phone perform a scan

# %%
import pandas
from sensible_raw.loaders import loader

# %% [markdown]
# ### Field description

# %%
loader.docs("bluetooth")
# Out:
#                                                                                                                                                                                                   bt_mac  \
# 0  A unique identifier for the scanned device. > 0 values represent users from the study and match the user_id column, values < 0 represent devices outside the study, values of -1 indicate empty scans
#
#                     class  \
# 0  Bluetooth device class
#
#                                                                                                                                                                                           rssi  \
# 0  Signal strength of the scanned device in dBm. Higher means stronger. Samples with a value of 0 indicate a device malfunction. It could still be used as a reasonable indicator of proximity
#
#                                  timestamp  \
# 0  Unix-time of the sample in milliseconds
#
# ...

# %% [markdown]
# ### Load data

# %%
loader.load_data("bluetooth", "january_2014", as_dataframe=True)
# Out:
#           bt_mac    class         id  rssi      timestamp  user
# 0       -1       -1        54458      0     1390181791000  518
# 1       -1       -1        54459      0     1390182093000  518
# 2       -1       -1        54460      0     1390182395000  518
# 3       -1       -1        54461      0     1390182695000  518
# 4       -1       -1        54462      0     1390182996000  518
# 5       -1       -1        54463      0     1390183296000  518
# 6       -1       -1        54464      0     1390183595000  518
# 7       -1       -1        54465      0     1390183896000  518
# 8       -1       -1        54466      0     1390184196000  518
# 9       -1       -1        54467      0     1390184496000  518
# 10      -1       -1        54468      0     1390184795000  518
# 11      -1       -1        54469      0     1390185096000  518
# 12      -1       -1        60669      0     1391038513000  518
# 13      -1       -1        60670      0     1391038813000  518
# ...

# %% [markdown]
# ### Data quality

# %%
# Plots the number of active users in each month of the experiment (September 2013 - February 2016)
# %run ../data_quality.py
# %matplotlib inline

plot_monthly_active_users('calllog')
