# %% [markdown]
# # Location raw

# %% [markdown]
# The location data as was extracted from the phone. The sampling was done every 5 minutes, but higher resolutions samples are also available due to opportunistic sampling.

# %%
import pandas
from sensible_raw.loaders import loader

# %% [markdown]
# ### Field description

# %%
loader.docs("location_raw")
# Out:
#                              accuracy                       lat  \
# 0  Accuracy of the location in meters  Latitude of the location
#
#                          lon  \
# 0  Longitude of the location
#
#                                                       provider  \
# 0  Provider of the location sample: 1=network, 2=fused, 3=gps.
#
#                                  timestamp  \
# 0  Unix-time of the sample in milliseconds
#
#                                                                                                                                      user
# 0  Unique identifier for each user. Note: it is an id, not a counter for users. Numbers higher than 850 doesn't mean there are more users

# %% [markdown]
# ### Load data

# %%
loader.load_data("location_raw", "january_2014", as_dataframe=True)
# Out:
#           accuracy        lat        lon  provider      timestamp  user
# 0               20  55.773409  12.474813         2  1390405046000   518
# 1               20  55.773413  12.474807         2  1390405106000   518
# 2               20  55.773410  12.474825         2  1390405166000   518
# 3               18  55.773379  12.474812         2  1390405229000   518
# 4               15  55.773382  12.474816         2  1390405233000   518
# 5               15  55.773382  12.474816         2  1390405234000   518
# 6               15  55.773382  12.474816         2  1390405235000   518
# 7               15  55.773382  12.474816         2  1390405236000   518
# 8               15  55.773382  12.474816         2  1390405237000   518
# 9               15  55.773382  12.474816         2  1390405238000   518
# 10              13  55.773384  12.474818         2  1390405240000   518
# 11              11  55.773385  12.474820         2  1390405252000   518
# ...

# %% [markdown]
# ### Data quality

# %%
# Plots the number of active users in each month of the experiment (September 2013 - February 2016)
# %run ../data_quality.py
# %matplotlib inline

plot_monthly_active_users('location_raw')
