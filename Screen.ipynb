# %% [markdown]
# # Screen

# %% [markdown]
# Screen on/off activity. The events are recorded both when the user turns the screen on/off, and when a call turns the screen on/off.

# %%
import pandas
from sensible_raw.loaders import loader

# %% [markdown]
# ### Field description

# %%
loader.docs("screen")
# Out:
#                                              screen_on  \
# 0  1 - screen was turned on, 0 - screen was turned off
#
#                                  timestamp  \
# 0  Unix-time of the sample in milliseconds
#
#                                                                                                                                      user
# 0  Unique identifier for each user. Note: it is an id, not a counter for users. Numbers higher than 850 doesn't mean there are more users

# %% [markdown]
# ### Load data

# %%
loader.load_data("screen", "january_2014", as_dataframe=True)
# Out:
#          screen_on      timestamp  user
# 0                1  1390460859000   228
# 1                0  1390460861000   228
# 2                1  1390460877000   228
# 3                0  1390460878000   228
# 4                1  1390461170000   228
# 5                1  1390513532000   228
# 6                0  1390513533000   228
# 7                1  1390513537000   228
# 8                0  1390513582000   228
# 9                1  1390516770000   228
# 10               0  1390516820000   228
# 11               0  1389244727000   228
# 12               1  1389245400000   228
# 13               0  1389245542000   228
# 14               1  1389248149000   228
# 15               0  1389248221000   228
# 16               1  1389248262000   228
# 17               0  1389248265000   228
# 18               1  1389248287000   228
# 19               1  1388949079000   228
# 20               0  1388949155000   228
# 21               1  1388949300000   228
# ...

# %% [markdown]
# ### Data quality

# %%
# Plots the number of active users in each month of the experiment (September 2013 - February 2016)
# %run ../data_quality.py
# %matplotlib inline

plot_monthly_active_users('screen')
